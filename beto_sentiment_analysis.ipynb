# %% [markdown]
# <a href="https://colab.research.google.com/github/angelicavelez/hugging_face/blob/main/beto_sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers

# %% [markdown]
# Model page: https://huggingface.co/finiteautomata/beto-sentiment-analysis
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/finiteautomata/beto-sentiment-analysis)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="finiteautomata/beto-sentiment-analysis")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/841 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/528 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/242k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/439M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/481k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# ...

# %%
pipe("Buenos dias a mi red de Linkedin")
# Out:
# [{'label': 'NEU', 'score': 0.8667851686477661}]

# %%
pipe("Estoy pensativo")
# Out:
# [{'label': 'NEU', 'score': 0.9936424493789673}]

# %%
pipe("Tengo una buena noticia, tengo una entrevista mañana, yei!")
# Out:
# [{'label': 'POS', 'score': 0.9963394403457642}]

# %%
pipe("Esa opinión no fue tan buena")
# Out:
# [{'label': 'NEG', 'score': 0.9938355088233948}]

# %%
pipe("El presidente del Gobierno, Pedro Sánchez, ha pospuesto su comparecencia en el Congreso sobre el caso Cerdán hasta el 9 de julio, en medio de crecientes tensiones políticas y demandas de explicaciones por parte de sus socios parlamentarios.")
# Out:
# [{'label': 'NEG', 'score': 0.9757454991340637}]

# %%
pipe("Hoy en Sant Joan Despí se espera un día soleado y caluroso, con temperaturas que alcanzarán los 32 °C y sin lluvias.")
# Out:
# [{'label': 'NEU', 'score': 0.9046934247016907}]

# %%
pipe("Hoy en Sant Joan Despí disfrutarás de un espectacular día soleado con 32 °C, ideal para planes al aire libre.")
# Out:
# [{'label': 'POS', 'score': 0.9985858201980591}]

# %%
pipe("Hoy en Sant Joan Despí el calor será intenso, con 32 °C y mucho sol, lo que resulta ser agobiante sin sombra.")
# Out:
# [{'label': 'NEG', 'score': 0.9900107979774475}]
